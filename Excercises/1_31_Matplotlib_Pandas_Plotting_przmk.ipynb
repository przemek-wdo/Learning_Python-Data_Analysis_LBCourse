# %% [markdown]
# <a href="https://colab.research.google.com/github/przemek-wdo/Learning_Python-Data_Analysis_LBCourse/blob/main/Excercises/1_31_Matplotlib_Pandas_Plotting_przmk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_31_Matplotlib Pandas Plotting.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# !pip install -U datasets
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ## 🟩 Job Posting Location Bar Plot (1.31.1)

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Top Job Locations (1.31.2)

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Job Postings Trend Line Plot (1.31.3)

# %%
monthly_job_counts = df['job_posted_date'].dt.month.value_counts().sort_index().reset_index()
monthly_job_counts = monthly_job_counts.rename(columns={'count':'Job Postings'})
monthly_job_counts.job_posted_date = pd.to_datetime(monthly_job_counts.job_posted_date, format='%m').dt.strftime('%b')
monthly_job_counts = monthly_job_counts.set_index('job_posted_date')
monthly_job_counts.plot(
    kind='line',
    figsize=(12, 6),
    xticks=range(12),
    title='Monthly Job Postings Trend',
    xlabel='Month',
    ylabel='Number of Job Postings'
)

# %% [markdown]
# ---
